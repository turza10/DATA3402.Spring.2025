# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class Counter:
  def __init__(self, max_value):
    self.value = 0
    self.max_value = max_value

  def increment(self):
        if self.value < self.max_value:
            self.value += 1
        else:
            print("Error: Counter has reached its maximum value.")

  def reset(self):
        self.value = 0

c = Counter(3)
c.increment()
c.increment()
c.increment()
c.increment()  # Should print error
print("Counter value after increments:", c.value)
c.reset()
print("Counter value after reset:", c.value)
# Out:
# Error: Counter has reached its maximum value.
# Counter value after increments: 3
# Counter value after reset: 0

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class Counter:
    def __init__(self, max_value):
        self.__value = 0
        self.__max_value = max_value

    def increment(self):
        if self.__value < self.__max_value:
            self.__value += 1
        else:
            print("Error: Counter has reached its maximum value.")

    def reset(self):
        self.__value = 0

    def get_value(self):
        return self.__value

    def get_max_value(self):
        return self.__max_value

    def is_at_max(self):
        return self.__value == self.__max_value

cp = Counter(2)
cp.increment()
print("Current value:", cp.get_value())
cp.increment()
print("At max?", cp.is_at_max())
cp.increment()  # Should print error
cp.reset()
print("Value after reset:", cp.get_value())
# Out:
# Current value: 1
# At max? True
# Error: Counter has reached its maximum value.
# Value after reset: 0

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class Rectangle:
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)


    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


r1 = Rectangle(length=8, width=7, x=5, y=10)

print("Coordinates of corner:", (r1.get_x(), r1.get_y()))
print("Length:", r1.get_length())
print("Width:", r1.get_width())
print("Area is", r1.area())
print("Perimeter is", r1.perimeter())
# Out:
# Coordinates of corner: (5, 10)
# Length: 8
# Width: 7
# Area is 56
# Perimeter is 30

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
import math


class Circle:
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    # Accessors
    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

c1 = Circle(radius=4, x=2, y=3)

print("Center coordinates:", (c1.get_x(), c1.get_y()))
print("Radius:", c1.get_radius())
print("Area is", round(c1.area(), 2))
print("Perimeter is", round(c1.perimeter(), 2))
# Out:
# Center coordinates: (2, 3)
# Radius: 4
# Area is 50.27
# Perimeter is 25.13

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your regtangle and circule classes to inherit from the base class and overload the functions accordingly.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

    @abstractmethod
    def perimeter(self):
        pass

    @abstractmethod
    def get_x(self):
        pass

    @abstractmethod
    def get_y(self):
        pass



class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y



class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


shapes = [
    Rectangle(length=6, width=3, x=0, y=0),
    Circle(radius=5, x=1, y=1)
]

for shape in shapes:
    print("\nNew shape:")
    print("Type:", type(shape).__name__)
    print("Area:", round(shape.area(), 2))
    print("Perimeter:", round(shape.perimeter(), 2))
    print("Position:", (shape.get_x(), shape.get_y()))
# Out:
# New shape:
# Type: Rectangle
# Area: 18
# Perimeter: 18
# Position: (0, 0)
#
# New shape:
# Type: Circle
# Area: 78.54
# Perimeter: 31.42
# Position: (1, 1)

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
class Triangle(Shape):
    def __init__(self, base, height, x, y):
        self.__base = base
        self.__height = height
        self.__x = x
        self.__y = y

    def area(self):
        return 0.5 * self.__base * self.__height

    def perimeter(self):
        hypotenuse = math.sqrt(self.__base**2 + self.__height**2)
        return self.__base + self.__height + hypotenuse

    def get_base(self):
        return self.__base

    def get_height(self):
        return self.__height

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

t1 = Triangle(base=6, height=8, x=0, y=0)

print("Base and height:", t1.get_base(), t1.get_height())
print("Coordinates of corner:", (t1.get_x(), t1.get_y()))
print("Area is", t1.area())
print("Perimeter is", round(t1.perimeter(), 2))
# Out:
# Base and height: 6 8
# Coordinates of corner: (0, 0)
# Area is 24.0
# Perimeter is 24.0

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

    @abstractmethod
    def perimeter(self):
        pass

    @abstractmethod
    def get_x(self):
        pass

    @abstractmethod
    def get_y(self):
        pass

    @abstractmethod
    def get_points(self):
        pass



class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_points(self):
        points = []
        for i in range(4):
            for j in range(4):
                if i == 0:  # bottom edge
                    x = self.__x + j * (self.__length / 4)
                    y = self.__y
                elif i == 1:  # right edge
                    x = self.__x + self.__length
                    y = self.__y + j * (self.__width / 4)
                elif i == 2:  # top edge
                    x = self.__x + self.__length - j * (self.__length / 4)
                    y = self.__y + self.__width
                else:  # left edge
                    x = self.__x
                    y = self.__y + self.__width - j * (self.__width / 4)
                points.append((x, y))
        return points


import math

class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def get_radius(self):
        return self.__radius

    def get_points(self):
        points = []
        for i in range(16):
            angle = 2 * math.pi * i / 16
            x = self.__x + self.__radius * math.cos(angle)
            y = self.__y + self.__radius * math.sin(angle)
            points.append((x, y))
        return points

class Triangle(Shape):
    def __init__(self, base, height, x, y):
        self.__base = base
        self.__height = height
        self.__x = x
        self.__y = y

    def area(self):
        return 0.5 * self.__base * self.__height

    def perimeter(self):
        hypotenuse = math.sqrt(self.__base**2 + self.__height**2)
        return self.__base + self.__height + hypotenuse

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def get_base(self):
        return self.__base

    def get_height(self):
        return self.__height

    def get_points(self):
        points = []

        # Base: (x, y) to (x + base, y)
        for i in range(6):
            x = self.__x + i * (self.__base / 6)
            y = self.__y
            points.append((x, y))

        # Height: (x, y) to (x, y + height)
        for i in range(5):
            x = self.__x + self.__base
            y = self.__y + i * (self.__height / 5)
            points.append((x, y))

        # Hypotenuse: (x + base, y + height) to (x, y)
        for i in range(5):
            x = self.__x + self.__base - i * (self.__base / 5)
            y = self.__y + self.__height - i * (self.__height / 5)
            points.append((x, y))

        return points[:16]

r2 = Rectangle(length=8, width=4, x=0, y=0)

points = r2.get_points()
print("Perimeter points of rectangle:")
for i, pt in enumerate(points):
    print(f"Point {i+1}: {pt}")
# Out:
# Perimeter points of rectangle:
# Point 1: (0.0, 0)
# Point 2: (2.0, 0)
# Point 3: (4.0, 0)
# Point 4: (6.0, 0)
# Point 5: (8, 0.0)
# Point 6: (8, 1.0)
# Point 7: (8, 2.0)
# Point 8: (8, 3.0)
# Point 9: (8.0, 4)
# Point 10: (6.0, 4)
# Point 11: (4.0, 4)
# Point 12: (2.0, 4)
# Point 13: (0, 4.0)
# Point 14: (0, 3.0)
# Point 15: (0, 2.0)
# Point 16: (0, 1.0)

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

    @abstractmethod
    def perimeter(self):
        pass

    @abstractmethod
    def get_x(self):
        pass

    @abstractmethod
    def get_y(self):
        pass

    @abstractmethod
    def get_points(self):
        pass

    @abstractmethod
    def contains(self, x, y):
        pass

    def overlaps(self, other):
        for (x, y) in self.get_points():
            if other.contains(x, y):
                return True
        for (x, y) in other.get_points():
            if self.contains(x, y):
                return True
        return False



class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_points(self):
        # As defined earlier...
        pass

    def contains(self, x, y):
        return (self.__x <= x <= self.__x + self.__length) and (self.__y <= y <= self.__y + self.__width)


class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def get_radius(self):
        return self.__radius

    def get_points(self):
        # As defined earlier...
        pass

    def contains(self, x, y):
        dx = x - self.__x
        dy = y - self.__y
        return dx**2 + dy**2 <= self.__radius**2


class Triangle(Shape):
    def __init__(self, base, height, x, y):
        self.__base = base
        self.__height = height
        self.__x = x
        self.__y = y

    def area(self):
        return 0.5 * self.__base * self.__height

    def perimeter(self):
        hypotenuse = math.sqrt(self.__base**2 + self.__height**2)
        return self.__base + self.__height + hypotenuse

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def get_base(self):
        return self.__base

    def get_height(self):
        return self.__height

    def get_points(self):
        # As defined earlier...
        pass

    def contains(self, px, py):
        # Triangle vertices
        x1, y1 = self.__x, self.__y
        x2, y2 = self.__x + self.__base, self.__y
        x3, y3 = self.__x, self.__y + self.__height

        # Using barycentric technique
        denom = ((y2 - y3)*(x1 - x3) + (x3 - x2)*(y1 - y3))
        if denom == 0:
            return False  # Degenerate triangle
        a = ((y2 - y3)*(px - x3) + (x3 - x2)*(py - y3)) / denom
        b = ((y3 - y1)*(px - x3) + (x1 - x3)*(py - y3)) / denom
        c = 1 - a - b

        return 0 <= a <= 1 and 0 <= b <= 1 and 0 <= c <= 1


r3 = Rectangle(length=6, width=4, x=1, y=2)

print("Point (3, 3) inside rectangle?", r3.contains(3, 3))
print("Point (10, 10) inside rectangle?", r3.contains(10, 10))


c2 = Circle(radius=5, x=0, y=0)

print("Point (3, 4) inside circle?", c2.contains(3, 4))
print("Point (6, 0) inside circle?", c2.contains(6, 0))


t2 = Triangle(base=6, height=6, x=0, y=0)

print("Point (2, 2) inside triangle?", t2.contains(2, 2))
print("Point (5, 5) inside triangle?", t2.contains(5, 5))
# Out:
# Point (3, 3) inside rectangle? True
# Point (10, 10) inside rectangle? False
# Point (3, 4) inside circle? True
# Point (6, 0) inside circle? False
# Point (2, 2) inside triangle? True
# Point (5, 5) inside triangle? False

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

    @abstractmethod
    def perimeter(self):
        pass

    @abstractmethod
    def get_x(self):
        pass

    @abstractmethod
    def get_y(self):
        pass

    @abstractmethod
    def get_points(self):
        pass

    @abstractmethod
    def contains(self, x, y):
        pass

    def overlaps(self, other):
        for (x, y) in self.get_points():
            if other.contains(x, y):
                return True
        for (x, y) in other.get_points():
            if self.contains(x, y):
                return True
        return False

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_points(self):
        points = []
        for i in range(4):
            for j in range(4):
                if i == 0:  # bottom
                    x = self.__x + j * (self.__length / 4)
                    y = self.__y
                elif i == 1:  # right
                    x = self.__x + self.__length
                    y = self.__y + j * (self.__width / 4)
                elif i == 2:  # top
                    x = self.__x + self.__length - j * (self.__length / 4)
                    y = self.__y + self.__width
                else:  # left
                    x = self.__x
                    y = self.__y + self.__width - j * (self.__width / 4)
                points.append((x, y))
        return points

    def contains(self, x, y):
        return (self.__x <= x <= self.__x + self.__length) and (self.__y <= y <= self.__y + self.__width)


import math

class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def get_radius(self):
        return self.__radius

    def get_points(self):
        points = []
        for i in range(16):
            angle = 2 * math.pi * i / 16
            x = self.__x + self.__radius * math.cos(angle)
            y = self.__y + self.__radius * math.sin(angle)
            points.append((x, y))
        return points

    def contains(self, x, y):
        dx = x - self.__x
        dy = y - self.__y
        return dx ** 2 + dy ** 2 <= self.__radius ** 2


class Triangle(Shape):
    def __init__(self, base, height, x, y):
        self.__base = base
        self.__height = height
        self.__x = x
        self.__y = y

    def area(self):
        return 0.5 * self.__base * self.__height

    def perimeter(self):
        hypotenuse = math.sqrt(self.__base ** 2 + self.__height ** 2)
        return self.__base + self.__height + hypotenuse

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def get_base(self):
        return self.__base

    def get_height(self):
        return self.__height

    def get_points(self):
        points = []
        for i in range(6):  # base
            x = self.__x + i * (self.__base / 6)
            y = self.__y
            points.append((x, y))
        for i in range(5):  # height
            x = self.__x + self.__base
            y = self.__y + i * (self.__height / 5)
            points.append((x, y))
        for i in range(5):  # hypotenuse
            x = self.__x + self.__base - i * (self.__base / 5)
            y = self.__y + self.__height - i * (self.__height / 5)
            points.append((x, y))
        return points[:16]

    def contains(self, px, py):
        x1, y1 = self.__x, self.__y
        x2, y2 = self.__x + self.__base, self.__y
        x3, y3 = self.__x, self.__y + self.__height

        denom = ((y2 - y3)*(x1 - x3) + (x3 - x2)*(y1 - y3))
        if denom == 0:
            return False
        a = ((y2 - y3)*(px - x3) + (x3 - x2)*(py - y3)) / denom
        b = ((y3 - y1)*(px - x3) + (x1 - x3)*(py - y3)) / denom
        c = 1 - a - b
        return 0 <= a <= 1 and 0 <= b <= 1 and 0 <= c <= 1


# Rectangle and Circle overlap
r4 = Rectangle(length=5, width=3, x=0, y=0)
c3 = Circle(radius=2, x=3, y=1)
print("Rectangle and Circle overlap?", r4.overlaps(c3))

# Rectangle and Triangle overlap
r5 = Rectangle(length=4, width=4, x=0, y=0)
t3 = Triangle(base=3, height=3, x=3, y=3)
print("Rectangle and Triangle overlap?", r5.overlaps(t3))

# Triangle and Circle — no overlap
t4 = Triangle(base=2, height=2, x=0, y=0)
c4 = Circle(radius=1, x=5, y=5)
print("Triangle and Circle overlap?", t4.overlaps(c4))
# Out:
# Rectangle and Circle overlap? True
# Rectangle and Triangle overlap? True
# Triangle and Circle overlap? False

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

    @abstractmethod
    def perimeter(self):
        pass

    @abstractmethod
    def get_x(self):
        pass

    @abstractmethod
    def get_y(self):
        pass

    @abstractmethod
    def get_points(self):
        pass

    @abstractmethod
    def contains(self, x, y):
        pass

    def overlaps(self, other):
        for (x, y) in self.get_points():
            if other.contains(x, y):
                return True
        for (x, y) in other.get_points():
            if self.contains(x, y):
                return True
        return False

    def paint(self, canvas):
        pass



class Canvas:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        self.data = [[' '] * width for _ in range(height)]
    def set_pixel(self, row, col, char='*'):
        if 0 <= row < self.height and 0 <= col < self.width:
            self.data[row][col] = char
    def display(self):
        print("\n".join(["".join(row) for row in self.data]))
    def h_line(self, x, y, length, char='*'):
        for i in range(x, x + length):
            self.set_pixel(y, i, char)
    def v_line(self, x, y, length, char='*'):
        for i in range(y, y + length):
            self.set_pixel(i, x, char)
    def line(self, x1, y1, x2, y2, char='*'):
        dx = abs(x2 - x1)
        dy = abs(y2 - y1)
        sx = 1 if x1 < x2 else -1
        sy = 1 if y1 < y2 else -1
        err = dx - dy

        while True:
            self.set_pixel(y1, x1, char)
            if x1 == x2 and y1 == y2:
                break
            e2 = 2 * err
            if e2 > -dy:
                err -= dy
                x1 += sx
            if e2 < dx:
                err += dx
                y1 += sy

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_points(self):
        points = []
        for i in range(4):
            for j in range(4):
                if i == 0:  # bottom
                    x = self.__x + j * (self.__length / 4)
                    y = self.__y
                elif i == 1:  # right
                    x = self.__x + self.__length
                    y = self.__y + j * (self.__width / 4)
                elif i == 2:  # top
                    x = self.__x + self.__length - j * (self.__length / 4)
                    y = self.__y + self.__width
                else:  # left
                    x = self.__x
                    y = self.__y + self.__width - j * (self.__width / 4)
                points.append((x, y))
        return points

    def contains(self, x, y):
        return (self.__x <= x <= self.__x + self.__length) and (self.__y <= y <= self.__y + self.__width)

    def paint(self, canvas):
      canvas.h_line(self.__x, self.__y, self.__length)
      canvas.h_line(self.__x, self.__y + self.__width, self.__length)
      canvas.v_line(self.__x, self.__y, self.__width)
      canvas.v_line(self.__x + self.__length, self.__y, self.__width)



import math

class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def get_radius(self):
        return self.__radius

    def get_points(self):
        points = []
        for i in range(16):
            angle = 2 * math.pi * i / 16
            x = self.__x + self.__radius * math.cos(angle)
            y = self.__y + self.__radius * math.sin(angle)
            points.append((x, y))
        return points

    def contains(self, x, y):
        dx = x - self.__x
        dy = y - self.__y
        return dx ** 2 + dy ** 2 <= self.__radius ** 2

    def paint(self, canvas):
      for (x, y) in self.get_points():
          canvas.set_pixel(round(y), round(x), 'o')



class Triangle(Shape):
    def __init__(self, base, height, x, y):
        self.__base = base
        self.__height = height
        self.__x = x
        self.__y = y

    def area(self):
        return 0.5 * self.__base * self.__height

    def perimeter(self):
        hypotenuse = math.sqrt(self.__base ** 2 + self.__height ** 2)
        return self.__base + self.__height + hypotenuse

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def get_base(self):
        return self.__base

    def get_height(self):
        return self.__height

    def get_points(self):
        points = []
        for i in range(6):  # base
            x = self.__x + i * (self.__base / 6)
            y = self.__y
            points.append((x, y))
        for i in range(5):  # height
            x = self.__x + self.__base
            y = self.__y + i * (self.__height / 5)
            points.append((x, y))
        for i in range(5):  # hypotenuse
            x = self.__x + self.__base - i * (self.__base / 5)
            y = self.__y + self.__height - i * (self.__height / 5)
            points.append((x, y))
        return points[:16]

    def contains(self, px, py):
        x1, y1 = self.__x, self.__y
        x2, y2 = self.__x + self.__base, self.__y
        x3, y3 = self.__x, self.__y + self.__height

        denom = ((y2 - y3)*(x1 - x3) + (x3 - x2)*(y1 - y3))
        if denom == 0:
            return False
        a = ((y2 - y3)*(px - x3) + (x3 - x2)*(py - y3)) / denom
        b = ((y3 - y1)*(px - x3) + (x1 - x3)*(py - y3)) / denom
        c = 1 - a - b
        return 0 <= a <= 1 and 0 <= b <= 1 and 0 <= c <= 1

    def paint(self, canvas):
      x1, y1 = self.__x, self.__y
      x2, y2 = self.__x + self.__base, self.__y
      x3, y3 = self.__x, self.__y + self.__height
      canvas.line(round(x1), round(y1), round(x2), round(y2))
      canvas.line(round(x2), round(y2), round(x3), round(y3))
      canvas.line(round(x3), round(y3), round(x1), round(y1))




class CompoundShape(Shape):
    def __init__(self):
        self.shapes = []

    def add(self, shape):
        self.shapes.append(shape)

    def area(self):
        return sum(shape.area() for shape in self.shapes)

    def perimeter(self):
        return sum(shape.perimeter() for shape in self.shapes)

    def get_x(self):
        return min(shape.get_x() for shape in self.shapes)

    def get_y(self):
        return min(shape.get_y() for shape in self.shapes)

    def get_points(self):
        points = []
        for shape in self.shapes:
            points.extend(shape.get_points())
        return points[:16]

    def contains(self, x, y):
        return any(shape.contains(x, y) for shape in self.shapes)

    def paint(self, canvas):
        for shape in self.shapes:
            shape.paint(canvas)



canvas = Canvas(width=40, height=20)

r = Rectangle(length=10, width=4, x=2, y=2)
c = Circle(radius=5, x=20, y=10)
t = Triangle(base=6, height=4, x=30, y=2)


scene = CompoundShape()
scene.add(r)
scene.add(c)
scene.add(t)

scene.paint(canvas)
canvas.display()
# Out:
#
#
#   ***********                 *******
#   *         *                 *   **
#   *         *                 *  *
#   *         *     o o o       ***
#   **********    o       o     *
#
#                o         o
#
#                o         o
#
#                o         o
#
#                 o       o
#                   o o o

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
class RasterDrawing:
    def __init__(self, width, height):
        self.canvas = Canvas(width, height)
        self.shapes = []

    def add_shape(self, shape):
        self.shapes.append(shape)

    def remove_last_shape(self):
        if self.shapes:
            self.shapes.pop()

    def clear_shapes(self):
        self.shapes = []

    def paint(self):
        # Reset canvas
        self.canvas = Canvas(self.canvas.width, self.canvas.height)
        for shape in self.shapes:
            shape.paint(self.canvas)
        self.canvas.display()

drawing = RasterDrawing(width=50, height=20)
drawing.add_shape(Rectangle(length=8, width=3, x=2, y=2))
drawing.add_shape(Circle(radius=4, x=25, y=10))
drawing.add_shape(Triangle(base=6, height=5, x=40, y=2))

print("Initial Drawing:")
drawing.paint()


drawing.remove_last_shape()
drawing.add_shape(Rectangle(length=10, width=2, x=35, y=15))

print("\nModified Drawing:")
drawing.paint()
# Out:
# Initial Drawing:
#
#
#   *********                             *******
#   *       *                             *    *
#   *       *                             *  **
#   ********                              * *
#                        o o o            **
#                       o     o           *
#                      o       o
#
#                      o       o
#
#                      o       o
#                       o     o
#                        o o o
#
#
#
#
#
#
# Modified Drawing:
#
#
#   *********
#   *       *
#   *       *
#   ********
#                        o o o
#                       o     o
#                      o       o
#
#                      o       o
#
#                      o       o
#                       o     o
#                        o o o
#                                    ***********
#                                    *         *
#                                    **********

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_points(self):
        points = []
        for i in range(4):
            for j in range(4):
                if i == 0:  # bottom
                    x = self.__x + j * (self.__length / 4)
                    y = self.__y
                elif i == 1:  # right
                    x = self.__x + self.__length
                    y = self.__y + j * (self.__width / 4)
                elif i == 2:  # top
                    x = self.__x + self.__length - j * (self.__length / 4)
                    y = self.__y + self.__width
                else:  # left
                    x = self.__x
                    y = self.__y + self.__width - j * (self.__width / 4)
                points.append((x, y))
        return points

    def contains(self, x, y):
        return (self.__x <= x <= self.__x + self.__length) and (self.__y <= y <= self.__y + self.__width)

    def paint(self, canvas):
      canvas.h_line(self.__x, self.__y, self.__length)
      canvas.h_line(self.__x, self.__y + self.__width, self.__length)
      canvas.v_line(self.__x, self.__y, self.__width)
      canvas.v_line(self.__x + self.__length, self.__y, self.__width)

    def __repr__(self):
      return f"Rectangle({self.__length}, {self.__width}, {self.__x}, {self.__y})"




import math

class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def get_radius(self):
        return self.__radius

    def get_points(self):
        points = []
        for i in range(16):
            angle = 2 * math.pi * i / 16
            x = self.__x + self.__radius * math.cos(angle)
            y = self.__y + self.__radius * math.sin(angle)
            points.append((x, y))
        return points

    def contains(self, x, y):
        dx = x - self.__x
        dy = y - self.__y
        return dx ** 2 + dy ** 2 <= self.__radius ** 2

    def paint(self, canvas):
      for (x, y) in self.get_points():
          canvas.set_pixel(round(y), round(x), 'o')

    def __repr__(self):
      return f"Circle({self.__radius}, {self.__x}, {self.__y})"




class Triangle(Shape):
    def __init__(self, base, height, x, y):
        self.__base = base
        self.__height = height
        self.__x = x
        self.__y = y

    def area(self):
        return 0.5 * self.__base * self.__height

    def perimeter(self):
        hypotenuse = math.sqrt(self.__base ** 2 + self.__height ** 2)
        return self.__base + self.__height + hypotenuse

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def get_base(self):
        return self.__base

    def get_height(self):
        return self.__height

    def get_points(self):
        points = []
        for i in range(6):  # base
            x = self.__x + i * (self.__base / 6)
            y = self.__y
            points.append((x, y))
        for i in range(5):  # height
            x = self.__x + self.__base
            y = self.__y + i * (self.__height / 5)
            points.append((x, y))
        for i in range(5):  # hypotenuse
            x = self.__x + self.__base - i * (self.__base / 5)
            y = self.__y + self.__height - i * (self.__height / 5)
            points.append((x, y))
        return points[:16]

    def contains(self, px, py):
        x1, y1 = self.__x, self.__y
        x2, y2 = self.__x + self.__base, self.__y
        x3, y3 = self.__x, self.__y + self.__height

        denom = ((y2 - y3)*(x1 - x3) + (x3 - x2)*(y1 - y3))
        if denom == 0:
            return False
        a = ((y2 - y3)*(px - x3) + (x3 - x2)*(py - y3)) / denom
        b = ((y3 - y1)*(px - x3) + (x1 - x3)*(py - y3)) / denom
        c = 1 - a - b
        return 0 <= a <= 1 and 0 <= b <= 1 and 0 <= c <= 1

    def paint(self, canvas):
      x1, y1 = self.__x, self.__y
      x2, y2 = self.__x + self.__base, self.__y
      x3, y3 = self.__x, self.__y + self.__height
      canvas.line(round(x1), round(y1), round(x2), round(y2))
      canvas.line(round(x2), round(y2), round(x3), round(y3))
      canvas.line(round(x3), round(y3), round(x1), round(y1))

    def __repr__(self):
      return f"Triangle({self.__base}, {self.__height}, {self.__x}, {self.__y})"


class CompoundShape(Shape):
    def __init__(self, shapes=None):
        self.shapes = shapes if shapes else []


    def add(self, shape):
        self.shapes.append(shape)

    def area(self):
        return sum(shape.area() for shape in self.shapes)

    def perimeter(self):
        return sum(shape.perimeter() for shape in self.shapes)

    def get_x(self):
        return min(shape.get_x() for shape in self.shapes)

    def get_y(self):
        return min(shape.get_y() for shape in self.shapes)

    def get_points(self):
        points = []
        for shape in self.shapes:
            points.extend(shape.get_points())
        return points[:16]

    def contains(self, x, y):
        return any(shape.contains(x, y) for shape in self.shapes)

    def paint(self, canvas):
        for shape in self.shapes:
            shape.paint(canvas)

    def __repr__(self):
      return f"CompoundShape({repr(self.shapes)})"

class RasterDrawing:
    def __init__(self, width, height):
        self.canvas = Canvas(width, height)
        self.shapes = []

    def add_shape(self, shape):
        self.shapes.append(shape)

    def remove_last_shape(self):
        if self.shapes:
            self.shapes.pop()

    def clear_shapes(self):
        self.shapes = []

    def paint(self):
        # Reset canvas
        self.canvas = Canvas(self.canvas.width, self.canvas.height)
        for shape in self.shapes:
            shape.paint(self.canvas)
        self.canvas.display()

    def save(self, filename):
      with open(filename, "w") as f:
        for shape in self.shapes:
            f.write(repr(shape) + "\n")

    def load(self, filename):
        self.clear_shapes()
        with open(filename, "r") as f:
            for line in f:
                shape = eval(line.strip())
                self.add_shape(shape)

drawing = RasterDrawing(50, 20)
drawing.add_shape(Rectangle(10, 4, 2, 2))
drawing.add_shape(Circle(5, 25, 10))
drawing.save("my_drawing.txt")


loaded = RasterDrawing(50, 20)
loaded.load("my_drawing.txt")
print("Loaded Drawing:")
loaded.paint()
# Out:
# Loaded Drawing:
#
#
#   ***********
#   *         *
#   *         *
#   *         *          o o o
#   **********         o       o
#
#                     o         o
#
#                     o         o
#
#                     o         o
#
#                      o       o
#                        o o o

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b

    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"

    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()


def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# foo(1,'hello')

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')
